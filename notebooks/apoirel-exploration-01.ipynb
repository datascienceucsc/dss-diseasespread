# %% [markdown]
# # Deng AI Exploration and Cleaning
# *Anders Poirel - 21-10-2019*

# %% [markdown]
# ## Reading the data

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os

# %%
RAW_DATA_PATH = "../data/raw/"

# %%
train_features = pd.read_csv(os.path.join(RAW_DATA_PATH, "train_features.csv"))
train_labels = pd.read_csv(os.path.join(RAW_DATA_PATH, "train_labels.csv"))
test_features = pd.read_csv(os.path.join(RAW_DATA_PATH, "test_features.csv"))

# %%
train_features.head()
# Out:
#   city  year  weekofyear week_start_date   ndvi_ne   ndvi_nw   ndvi_se  \
# 0   sj  1990          18      1990-04-30  0.122600  0.103725  0.198483
# 1   sj  1990          19      1990-05-07  0.169900  0.142175  0.162357
# 2   sj  1990          20      1990-05-14  0.032250  0.172967  0.157200
# 3   sj  1990          21      1990-05-21  0.128633  0.245067  0.227557
# 4   sj  1990          22      1990-05-28  0.196200  0.262200  0.251200
#
#     ndvi_sw  precipitation_amt_mm  reanalysis_air_temp_k  ...  \
# 0  0.177617                 12.42             297.572857  ...
# 1  0.155486                 22.82             298.211429  ...
# 2  0.170843                 34.54             298.781429  ...
# 3  0.235886                 15.36             298.987143  ...
# 4  0.247340                  7.52             299.518571  ...
#
#    reanalysis_precip_amt_kg_per_m2  reanalysis_relative_humidity_percent  \
# 0                            32.00                             73.365714
# ...

# %%
train_labels.head()
# Out:
#   city  year  weekofyear  total_cases
# 0   sj  1990          18            4
# 1   sj  1990          19            5
# 2   sj  1990          20            4
# 3   sj  1990          21            3
# 4   sj  1990          22            6

# %%
train_features.isna().sum()h
# Out:
# city                                       0
# year                                       0
# weekofyear                                 0
# week_start_date                            0
# ndvi_ne                                  194
# ndvi_nw                                   52
# ndvi_se                                   22
# ndvi_sw                                   22
# precipitation_amt_mm                      13
# reanalysis_air_temp_k                     10
# reanalysis_avg_temp_k                     10
# reanalysis_dew_point_temp_k               10
# reanalysis_max_air_temp_k                 10
# reanalysis_min_air_temp_k                 10
# reanalysis_precip_amt_kg_per_m2           10
# reanalysis_relative_humidity_percent      10
# reanalysis_sat_precip_amt_mm              13
# reanalysis_specific_humidity_g_per_kg     10
# reanalysis_tdtr_k                         10
# station_avg_temp_c                        43
# station_diur_temp_rng_c                   43
# ...

# %% [markdown]
# There are many missing values in this dataset so we will require some form of imputation

# %% [markdown]
# ## Basic stats
#
# Before anything, let's compute some basic statistics about our data:

# %%
train_features.loc[:, 'ndvi_ne':].describe()
# Out:
#            ndvi_ne      ndvi_nw      ndvi_se      ndvi_sw  \
# count  1262.000000  1404.000000  1434.000000  1434.000000
# mean      0.142294     0.130553     0.203783     0.202305
# std       0.140531     0.119999     0.073860     0.083903
# min      -0.406250    -0.456100    -0.015533    -0.063457
# 25%       0.044950     0.049217     0.155087     0.144209
# 50%       0.128817     0.121429     0.196050     0.189450
# 75%       0.248483     0.216600     0.248846     0.246982
# max       0.508357     0.454429     0.538314     0.546017
#
#        precipitation_amt_mm  reanalysis_air_temp_k  reanalysis_avg_temp_k  \
# count           1443.000000            1446.000000            1446.000000
# mean              45.760388             298.701852             299.225578
# std               43.715537               1.362420               1.261715
# min                0.000000             294.635714             294.892857
# ...

# %%
train_labels['total_cases'].describe()
# Out:
# count    1456.000000
# mean       24.675137
# std        43.596000
# min         0.000000
# 25%         5.000000
# 50%        12.000000
# 75%        28.000000
# max       461.000000
# Name: total_cases, dtype: float64

# %% [markdown]
# Let's see if there is a significant difference in these between the cities:

# %%
train_iq = train_features[train_features['city'] == 'iq']
train_sj = train_features[train_features['city'] == 'sj']

# %%
train_iq.loc[:, 'ndvi_ne':].describe()
# Out:
#           ndvi_ne     ndvi_nw     ndvi_se     ndvi_sw  precipitation_amt_mm  \
# count  517.000000  517.000000  517.000000  517.000000            516.000000
# mean     0.263869    0.238783    0.250126    0.266779             64.245736
# std      0.081370    0.076751    0.077354    0.086345             35.218995
# min      0.061729    0.035860    0.029880    0.064183              0.000000
# 25%      0.200000    0.179540    0.194743    0.204129             39.105000
# 50%      0.263643    0.232971    0.249800    0.262143             60.470000
# 75%      0.319971    0.293929    0.302300    0.325150             85.757500
# max      0.508357    0.454429    0.538314    0.546017            210.830000
#
#        reanalysis_air_temp_k  reanalysis_avg_temp_k  \
# count             516.000000             516.000000
# mean              297.869538             299.133043
# std                 1.170997               1.332073
# min               294.635714             294.892857
# ...

# %%
train_sj.loc[:, 'ndvi_ne':].describe()
# Out:
#           ndvi_ne     ndvi_nw     ndvi_se     ndvi_sw  precipitation_amt_mm  \
# count  745.000000  887.000000  917.000000  917.000000            927.000000
# mean     0.057925    0.067469    0.177655    0.165956             35.470809
# std      0.107153    0.092479    0.057166    0.056073             44.606137
# min     -0.406250   -0.456100   -0.015533   -0.063457              0.000000
# 25%      0.004500    0.016425    0.139283    0.129157              0.000000
# 50%      0.057700    0.068075    0.177186    0.165971             20.800000
# 75%      0.111100    0.115200    0.212557    0.202771             52.180000
# max      0.493400    0.437100    0.393129    0.381420            390.600000
#
#        reanalysis_air_temp_k  reanalysis_avg_temp_k  \
# count             930.000000             930.000000
# mean              299.163653             299.276920
# std                 1.236429               1.218637
# min               295.938571             296.114286
# ...

# %% [markdown]
# Observations:
#
# - Iquito has higher precipitation that San Juan
# - Temperatures are fairly similar in both cities
# - Iquito has pretty uniform vegetation in all directions, San Juan has higher vegetion S than N
# - SJ has higher humididty, though it is more variable

# %% [markdown]
# ## Time series aspect
#
# Put all information into one dataframe and convert dates to `datetime` format to facilitate visualization.

# %%
train = train_features
train['total_cases'] = train_labels['total_cases']
train['week_start_date'] = pd.to_datetime(train['week_start_date'])

# %%
sns.set()

# %%
ts_c = sns.lineplot(x = 'week_start_date', y = 'total_cases', hue = 'city', data = train_features) 
ts_c.set(title = 'Number of cases per week', xlabel = 'date', ylabel = 'total cases')
# Out:
# [Text(0, 0.5, 'total cases'),
#  Text(0.5, 0, 'date'),
#  Text(0.5, 1.0, 'Number of cases per week')]

# %% [markdown]
# ### Visualization of each feature as a time series
